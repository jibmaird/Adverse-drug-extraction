# %%
import pandas as pd
import numpy as np
import sys

maxInt = sys.maxsize
csv.field_size_limit(maxInt)
# Out:
# 9223372036854775807

# %%
data_d = "/home/jibmaird/Data/Corpora/ADE-v2/Exper/Biobert/benchmark/"

# %%
train_d = pd.read_csv(data_d+"train.tsv", header=None,delimiter='\t',encoding="utf-8",engine="python",error_bad_lines=False)
# Out:
# Skipping line 48644: unexpected end of data

# %%
train_dev_d = pd.read_csv(data_d+"train_dev.tsv", delimiter='\t',encoding="latin1",engine="python",error_bad_lines=False)

# %%
train_dev_d.tail(10)
train_d.tail(10)
# Out:
#           1                                      Mycobacterium  B
# 48632  4081                                     sulphasalazine  B
# 48633  4081                                           syndrome  I
# 48634  4081  \tO\n4081\t,\tO\n4081\ta\tO\n4081\trare\tO\n40...  O
# 48635  4133                                                off  O
# 48636  4133  \tO\n4133\tstate\tO\n4133\tUPDRS\tO\n4133\tmot...  O
# 48637  4135                                           indirect  O
# 48638  4135  \tO\n4135\tpathway\tO\n4135\t;\tO\n4135\t(\tO\...  O
# 48639  4305                                              acute  O
# 48640  4305                          \tO\n4305\tand\tO\n4305\t  O
# 48641  4305                                            chronic  O

# %%
full_d = train_d
full_d.append(train_dev_d,sort=False)
# Out:
#           1 Mycobacterium    B   Chlorambucil    O
# 0         1       marinum    I            NaN  NaN
# 1         1     infection    I            NaN  NaN
# 2         1  complicating    O            NaN  NaN
# 3         1         Crohn    O            NaN  NaN
# 4         1             '    O            NaN  NaN
# ...     ...           ...  ...            ...  ...
# 95984  4547           NaN  NaN             of    O
# 95985  4547           NaN  NaN  inappropriate    O
# 95986  4547           NaN  NaN       naloxone    O
# 95987  4547           NaN  NaN            use    O
# 95988  4547           NaN  NaN              .    O
#
# [144631 rows x 5 columns]

# %%
full_d.tail(10)
# Out:
#           1                                      Mycobacterium  B
# 48632  4081                                     sulphasalazine  B
# 48633  4081                                           syndrome  I
# 48634  4081  \tO\n4081\t,\tO\n4081\ta\tO\n4081\trare\tO\n40...  O
# 48635  4133                                                off  O
# 48636  4133  \tO\n4133\tstate\tO\n4133\tUPDRS\tO\n4133\tmot...  O
# 48637  4135                                           indirect  O
# 48638  4135  \tO\n4135\tpathway\tO\n4135\t;\tO\n4135\t(\tO\...  O
# 48639  4305                                              acute  O
# 48640  4305                          \tO\n4305\tand\tO\n4305\t  O
# 48641  4305                                            chronic  O
